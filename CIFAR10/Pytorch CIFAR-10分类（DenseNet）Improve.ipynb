# %% [markdown]
# **Pytorch一般有以下几个流程**
#
#
# ### 1.数据读取
#
# ### 2.数据处理
#
# ### 3.搭建网络
#
# ### 4.模型训练
#
# ### 5.模型上线

# %% [markdown]
# ### 1.数据读取
# CIFAR-10 是由 Hinton 的学生 Alex Krizhevsky 和 Ilya Sutskever 整理的一个用于识别普适物体的小型数据集。一共包含 10 个类别的 RGB 彩色图 片：飞机（ arplane ）、汽车（ automobile ）、鸟类（ bird ）、猫（ cat ）、鹿（ deer ）、狗（ dog ）、蛙类（ frog ）、马（ horse ）、船（ ship ）和卡车（ truck ）。图片的尺寸为 32×32 ，数据集中一共有 50000 张训练圄片和 10000 张测试图片。
#
# 与 MNIST 数据集中目比， CIFAR-10 具有以下不同点：
#
#     • CIFAR-10 是 3 通道的彩色 RGB 图像，而 MNIST 是灰度图像。
#     • CIFAR-10 的图片尺寸为 32×32， 而 MNIST 的图片尺寸为 28×28，比 MNIST 稍大。
#     • 相比于手写字符， CIFAR-10 含有的是现实世界中真实的物体，不仅噪声很大，而且物体的比例、 特征都不尽相同，这为识别带来很大困难。

# %% [markdown]
# 首先使用`torchvision`加载和归一化我们的训练数据和测试数据。
#
#     a、`torchvision`这个东西，实现了常用的一些深度学习的相关的图像数据的加载功能，比如cifar10、Imagenet、Mnist等等的，保存在`torchvision.datasets`模块中。
#
#     b、同时，也封装了一些处理数据的方法。保存在`torchvision.transforms`模块中
#
#     c、还封装了一些模型和工具封装在相应模型中,比如`torchvision.models`当中就包含了AlexNet，VGG，ResNet，SqueezeNet等模型。

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torch.nn.functional as F
from torchsummary import summary
torch.__version__
# Out:
# '1.8.1+cu101'

# %%
# import tensorflow as tf
# import os
# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' # 忽略低级别的警告
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
# # The GPU id to use, usually either "0" or "1"
# os.environ["CUDA_VISIBLE_DEVICES"]="0"
# config = tf.compat.v1.ConfigProto()
# config.gpu_options.per_process_gpu_memory_fraction = 0.8
# # config.gpu_options.allow_growth = True
# session = tf.compat.v1.Session(config=config)

# %% [markdown]
# **由于torchvision的datasets的输出是[0,1]的PILImage，所以我们先先归一化为[-1,1]的Tensor**
#
# 首先定义了一个变换transform，利用的是上面提到的transforms模块中的Compose( )把多个变换组合在一起，可以看到这里面组合了ToTensor和Normalize这两个变换
#
# `transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))`前面的（0.5，0.5，0.5） 是 R G B 三个通道上的均值， 后面(0.5, 0.5, 0.5)是三个通道的标准差，注意通道顺序是 R G B ，用过opencv的同学应该知道openCV读出来的图像是 BRG顺序。这两个tuple数据是用来对RGB 图像做归一化的，如其名称 Normalize 所示这里都取0.5只是一个近似的操作，实际上其均值和方差并不是这么多，但是就这个示例而言 影响可不计。精确值是通过分别计算R,G,B三个通道的数据算出来的。

# %%
transform = transforms.Compose([
#     transforms.CenterCrop(224),

    transforms.RandomCrop(32,padding=4), # 数据增广
    transforms.RandomHorizontalFlip(),  # 数据增广
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %% [markdown]
#  `trainloader`其实是一个比较重要的东西，我们后面就是通过`trainloader`把数据传入网络，当然这里的`trainloader`其实是个变量名，可以随便取，重点是他是由后面的`torch.utils.data.DataLoader()`定义的，这个东西来源于`torch.utils.data`模块

# %%
Batch_Size = 128

# %%
trainset = datasets.CIFAR10(root='./data', train=True,download=True, transform=transform)
testset = datasets.CIFAR10(root='./data',train=False,download=True,transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=Batch_Size,shuffle=True, num_workers=8)
testloader = torch.utils.data.DataLoader(testset, batch_size=Batch_Size,shuffle=True, num_workers=8)
classes = ('plane', 'car', 'bird', 'cat','deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ### 2. 查看数据（格式，大小，形状）

# %%
classes = trainset.classes
classes
# Out:
# ['airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck']

# %%
trainset.class_to_idx
# Out:
# {'airplane': 0,
#  'automobile': 1,
#  'bird': 2,
#  'cat': 3,
#  'deer': 4,
#  'dog': 5,
#  'frog': 6,
#  'horse': 7,
#  'ship': 8,
#  'truck': 9}

# %%
trainset.data.shape #50000是图片数量，32x32是图片大小，3是通道数量RGB
# Out:
# (50000, 32, 32, 3)

# %%
#查看数据类型
print(type(trainset.data))
print(type(trainset))
# Out:
# <class 'numpy.ndarray'>
# <class 'torchvision.datasets.cifar.CIFAR10'>

# %% [markdown]
# ### 总结：
#
#     `trainset.data.shape`是标准的numpy.ndarray类型，其中50000是图片数量，32x32是图片大小，3是通道数量RGB；
#     `trainset`是标准的？？类型，其中50000为图片数量，0表示取前面的数据，2表示3通道数RGB，32*32表示图片大小
#
#  ### 3. 查看图片

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.imshow(trainset.data[0])
im,label = iter(trainloader).next()

# %% [markdown]
# ### np.ndarray转为torch.Tensor
#
# 在深度学习中，原始图像需要转换为深度学习框架自定义的数据格式，在pytorch中，需要转为`torch.Tensor`。
# pytorch提供了`torch.Tensor` 与`numpy.ndarray`转换为接口：
#
# 方法名|作用
# --|--
# `torch.from_numpy(xxx)`|`numpy.ndarray`转为torch.Tensor
# `tensor1.numpy()`|获取tensor1对象的numpy格式数据
#
# `torch.Tensor` 高维矩阵的表示： N x C x H x W
#
# `numpy.ndarray` 高维矩阵的表示：N x H x W x C
#
# 因此在两者转换的时候需要使用`numpy.transpose( )` 方法 。

# %%
def imshow(img):
    img = img / 2 + 0.5
    img = np.transpose(img.numpy(),(1,2,0))
    plt.imshow(img)

# %%
imshow(im[0])

# %%
im[0].shape
# Out:
# torch.Size([3, 32, 32])

# %%
plt.figure(figsize=(8,12))
imshow(torchvision.utils.make_grid(im[:32]))

# %% [markdown]
# ### 4.定义网络（DenseNet）
# 之前的ResNet通过前层与后层的“短路连接”（Shortcuts），加强了前后层之间的信息流通，在一定程度上缓解了梯度消失现象，从而**可以将神经网络搭建得很深**。更进一步，DenseNet最大化了这种前后层信息交流，通过建立**前面所有层与后面层的密集连接**，实现了特征在通道维度上的复用，使其可以在参数与计算量更少的情况下实现比ResNet更优的性能。如果想详细了解并查看论文，可以看我的另一篇博客[【论文泛读】 DenseNet：稠密连接的卷积网络](https://blog.csdn.net/weixin_45508265/article/details/119069665)
#
# DenseNet 和 ResNet 不同在于 ResNet 是跨层求和，而 DenseNet 是跨层将特征在通道维度进行拼接，下面可以看看他们两者的图示
#
# 这个是最标准的卷积神经网络
#
# ![dense1.png](attachment:dense1.png)

# %% [markdown]
# 这是ResNet，是跨层求和
# ![image.png](attachment:image.png)

# %% [markdown]
# 这个就是DenseNet，是跨层将特征在通道维度进行拼接
# ![image.png](attachment:image.png)

# %% [markdown]
# DenseNet的网络架构如下图所示，了便于下采样的实现，我们将网络划分为多个稠密连接的dense block，网络由多个Dense Block与中间的卷积池化组成，核心就在Dense Block中。Dense Block中的黑点代表一个卷积层，其中的多条黑线代表数据的流动，每一层的输入由前面的所有卷积层的输出组成。注意这里使用了通道拼接（Concatnate）操作，而非ResNet的逐元素相加操作。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 我们将每个block之间的层称为过渡层，完成卷积和池化的操作。在我们的实验中，过渡层由BN层、1x1卷积层和2x2平均池化层组成。
#
#
#
# 具体的Block实现细节如下图所示，每一个Block由若干个Bottleneck的卷积层组成，对应上面图中的黑点。Bottleneck由BN、ReLU、1×1卷积、BN、ReLU、3×3卷积的顺序构成，也被称为DenseNet-B结构。其中1x1 Conv得到 4k 个特征图它起到的作用是降低特征数量，从而提升计算效率。
# ![image.png](attachment:image.png)

# %% [markdown]
# 关于Block，有以下4个细节需要注意：
#
# 1. 每一个Bottleneck输出的特征通道数是相同的，例如这里的32。同时可以看到，经过Concatnate操作后的通道数是按32的增长量增加的，因此这个32也被称为GrowthRate。
# 2. 这里1×1卷积的作用是固定输出通道数，达到降维的作用。当几十个Bottleneck相连接时，Concatnate后的通道数会增加到上千，如果不增加1×1的卷积来降维，后续3×3卷积所需的参数量会急剧增加。1×1卷积的通道数通常是GrowthRate的4倍。
# 3. 上图中的特征传递方式是直接将前面所有层的特征Concatnate后传到下一层，这种方式与具体代码实现的方式是一致的。
# 4. Block采用了激活函数在前、卷积层在后的顺序，这与一般的网络上是不同的。
#
# ![img](.\img\densenet.gif)

# %% [markdown]
# ### DenseNet 的网络结构
#
# 在ImageNet数据集上的网络如下图所示
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 由于我是对CIFAR进行实验，而论文中给出的是ImageNet的网络模型，所以由于数据集的不同，模型稍微有些不同
#
# ![dense_cifar.jpg](attachment:dense_cifar.jpg)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu' # 判断是否用GPU
device
# Out:
# 'cuda'

# %% [markdown]
# #### Bottleneck

# %%
class Bottleneck(nn.Module):
    """
    Dense Block
    这里的growth_rate=out_channels, 就是每个Block自己输出的通道数。
    先通过1x1卷积层，将通道数缩小为4 * growth_rate，然后再通过3x3卷积层降低到growth_rate。
    """
    # 通常1×1卷积的通道数为GrowthRate的4倍
    expansion = 4
    
    def __init__(self, in_channels, growth_rate):
        super(Bottleneck, self).__init__()
        zip_channels = self.expansion * growth_rate
        self.features = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.ReLU(True),
            nn.Conv2d(in_channels, zip_channels, kernel_size=1, bias=False),
            nn.BatchNorm2d(zip_channels),
            nn.ReLU(True),
            nn.Conv2d(zip_channels, growth_rate, kernel_size=3, padding=1, bias=False)
        )
        
    def forward(self, x):
        out = self.features(x)
        out = torch.cat([out, x], 1)
        return out

# %% [markdown]
# 我们验证一下输出的 channel 是否正确

# %%
test_net = Bottleneck(3, 5)
test_x = torch.zeros(1, 3, 32, 32)
print('input shape: {} x {} x {}'.format(test_x.shape[1], test_x.shape[2], test_x.shape[3]))
test_y = test_net(test_x)
print('output shape: {} x {} x {}'.format(test_y.shape[1], test_y.shape[2], test_y.shape[3]))
# Out:
# input shape: 3 x 32 x 32
# output shape: 8 x 32 x 32

# %% [markdown]
# #### Transition

# %%
class Transition(nn.Module):
    """
    改变维数的Transition层 具体包括BN、ReLU、1×1卷积（Conv）、2×2平均池化操作
    先通过1x1的卷积层减少channels，再通过2x2的平均池化层缩小feature-map
    """
    # 1×1卷积的作用是降维，起到压缩模型的作用，而平均池化则是降低特征图的尺寸。
    def __init__(self, in_channels, out_channels):
        super(Transition, self).__init__()
        self.features = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.ReLU(True),
            nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False),
            nn.AvgPool2d(2)
        )
        
    def forward(self, x):
        out = self.features(x)
        return out

# %% [markdown]
# 验证一下过渡层是否正确

# %%
test_net = Transition(3, 12)
test_x = torch.zeros(1, 3, 96, 96)
print('input shape: {} x {} x {}'.format(test_x.shape[1], test_x.shape[2], test_x.shape[3]))
test_y = test_net(test_x)
print('output shape: {} x {} x {}'.format(test_y.shape[1], test_y.shape[2], test_y.shape[3]))
# Out:
# input shape: 3 x 96 x 96
# output shape: 12 x 48 x 48

# %% [markdown]
# #### DenseNet-BC

# %%
# DesneNet-BC
# B 代表 bottleneck layer(BN-RELU-CONV(1x1)-BN-RELU-CONV(3x3))
# C 代表压缩系数(0<=theta<=1)
import math
class DenseNet(nn.Module):
    """
    Dense Net
    paper中growth_rate取12，维度压缩的参数θ，即reduction取0.5
    且初始化方法为kaiming_normal()
    num_blocks为每段网络中的DenseBlock数量
    DenseNet和ResNet一样也是六段式网络（一段卷积+四段Dense+平均池化层），最后FC层。
    第一段将维数从3变到2 * growth_rate
    
    (3, 32, 32) -> [Conv2d] -> (24, 32, 32) -> [layer1] -> (48, 16, 16) -> [layer2]
  ->(96, 8, 8) -> [layer3] -> (192, 4, 4) -> [layer4] -> (384, 4, 4) -> [AvgPool]
  ->(384, 1, 1) -> [Linear] -> (10)
    
    """
    def __init__(self, num_blocks, growth_rate=12, reduction=0.5, num_classes=10):
        super(DenseNet, self).__init__()
        self.growth_rate = growth_rate
        self.reduction = reduction
        
        num_channels = 2 * growth_rate
        
        self.features = nn.Conv2d(3, num_channels, kernel_size=3, padding=1, bias=False)
        self.layer1, num_channels = self._make_dense_layer(num_channels, num_blocks[0])
        self.layer2, num_channels = self._make_dense_layer(num_channels, num_blocks[1])
        self.layer3, num_channels = self._make_dense_layer(num_channels, num_blocks[2])
        self.layer4, num_channels = self._make_dense_layer(num_channels, num_blocks[3], transition=False)
        self.avg_pool = nn.Sequential(
            nn.BatchNorm2d(num_channels),
            nn.ReLU(True),
            nn.AvgPool2d(4),
        )
        self.classifier = nn.Linear(num_channels, num_classes)
        
        self._initialize_weight()
        
    def _make_dense_layer(self, in_channels, nblock, transition=True):
        layers = []
        for i in range(nblock):
            layers += [Bottleneck(in_channels, self.growth_rate)]
            in_channels += self.growth_rate
        out_channels = in_channels
        if transition:
            out_channels = int(math.floor(in_channels * self.reduction))
            layers += [Transition(in_channels, out_channels)]
        return nn.Sequential(*layers), out_channels
    
    def _initialize_weight(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight.data)
                if m.bias is not None:
                    m.bias.data.zero_()
    
    def forward(self, x):
        out = self.features(x)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.avg_pool(out)
        out = out.view(out.size(0), -1)
        out = self.classifier(out)
        return out

# %%
def DenseNet121():
    return DenseNet([6,12,24,16], growth_rate=32)

def DenseNet169():
    return DenseNet([6,12,32,32], growth_rate=32)

def DenseNet201():
    return DenseNet([6,12,48,32], growth_rate=32)

def DenseNet161():
    return DenseNet([6,12,36,24], growth_rate=48)

def densenet_cifar():
    return DenseNet([6,12,24,16], growth_rate=12)

net = DenseNet121().to(device)

# %%
summary(net,(3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#             Conv2d-4          [-1, 128, 32, 32
#      BatchNorm2d-409            [-1, 960, 4, 4]           1,920
#             ReLU-410            [-1, 960, 4, 4]               0
#           Conv2d-411            [-1, 128, 4, 4]         122,880
#      BatchNorm2d-412            [-1, 128, 4, 4]             256
#             ReLU-413            [-1, 128, 4, 4]               0
#           Conv2d-414             [-1, 32, 4, 4]          36,864
#       Bottleneck-415            [-1, 992, 4, 4]               0
#      BatchNorm2d-416            [-1, 992, 4, 4]           1,984
#             ReLU-417            [-1, 992, 4, 4]               0
#           Conv2d-418            [-1, 128, 4, 4]         126,976
#      BatchNorm2d-419            [-1, 128, 4, 4]             256
#             ReLU-420            [-1, 128, 4, 4]               0
#           Conv2d-421             [-1, 32, 4, 4]          36,864
#       Bottleneck-422           [-1, 1024, 4, 4]               0
#      BatchNorm2d-423           [-1, 1024, 4, 4]           2,048
#             ReLU-424           [-1, 1024, 4, 4]               0
#        AvgPool2d-425           [-1, 1024, 1, 1]               0
#           Linear-426                   [-1, 10]          10,250
# ================================================================
# Total params: 6,956,298
# Trainable params: 6,956,298
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 115.98
# Params size (MB): 26.54
# Estimated Total Size (MB): 142.52
# ----------------------------------------------------------------

# %%
print(net)
# Out:
# DenseNet(
#   (features): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (1): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (2): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (3): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (4): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (5): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (6): Transition(
#       (features): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (1): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (2): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (3): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (4): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (5): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (6): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (7): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (8): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (9): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (10): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (11): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (12): Transition(
#       (features): Sequential(
#         (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (1): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (2): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (3): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (4): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (5): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (6): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (7): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (8): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (9): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (10): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (11): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (12): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (13): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (14): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (15): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (16): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (17): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (18): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (19): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (20): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (21): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (22): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (23): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (24): Transition(
#       (features): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (1): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (2): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (3): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (4): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (5): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (6): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (7): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (8): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (9): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (10): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (11): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (12): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (13): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (14): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (15): Bottleneck(
#       (features): Sequential(
#         (0): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (avg_pool): Sequential(
#     (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): ReLU(inplace=True)
#     (2): AvgPool2d(kernel_size=4, stride=4, padding=0)
#   )
#   (classifier): Linear(in_features=1024, out_features=10, bias=True)
# )

# %%
# 测试
x = torch.randn(2, 3, 32, 32).to(device)
y = net(x)
print(y.shape)
# Out:
# torch.Size([2, 10])

# %%
net = densenet_cifar().to(device)
if device == 'cuda':
    net = nn.DataParallel(net)
    # 当计算图不会改变的时候（每次输入形状相同，模型不改变）的情况下可以提高性能，反之则降低性能
    torch.backends.cudnn.benchmark = True

# %% [markdown]
# ### 5. 定义损失函数和优化器
#
# pytorch将深度学习中常用的优化方法全部封装在torch.optim之中，所有的优化方法都是继承基类optim.Optimizier
#
# 损失函数是封装在神经网络工具箱nn中的,包含很多损失函数

# %%
import torch.optim as optim
optimizer = optim.SGD(net.parameters(), lr=1e-1, momentum=0.9, weight_decay=1e-4)
criterion = nn.CrossEntropyLoss()
# scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.5,verbose=True,patience = 5,min_lr = 0.000001) # 动态更新学习率
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[10, 15], gamma=0.1)

import time
epoch = 20

# %%
lr = 1e-1
momentum = 0.9
weight_decay = 1e-4

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=lr, momentum=momentum, weight_decay=weight_decay)
# 论文原文的batch_size设置为64，epoch为300，在训练到50%和75%的epoch的时候，衰减学习率为原先的1/10
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[150, 225])
epoch = 300

# %% [markdown]
# ### 6. 训练

# %%
import os
if not os.path.exists('./model'):
    os.makedirs('./model')
else:
    print('文件已存在')
save_path = './model/Denset_improve.pth'
# Out:
# 文件已存在

# %%
from utils import train2
from utils import plot_history
Acc, Loss, Lr = train2(net, trainloader, testloader, epoch, optimizer, criterion, scheduler, save_path, verbose = True)
# Out:
# Epoch [  1/300]  Train Loss:1.452688  Train Acc:46.93% Test Loss:1.180509  Test Acc:59.25%  Learning Rate:0.100000	Time 03:19
# Epoch [  2/300]  Train Loss:0.931063  Train Acc:67.03% Test Loss:0.884387  Test Acc:68.88%  Learning Rate:0.100000	Time 03:07
# Epoch [  3/300]  Train Loss:0.701024  Train Acc:75.33% Test Loss:0.755415  Test Acc:73.94%  Learning Rate:0.100000	Time 03:19
# Epoch [  4/300]  Train Loss:0.588079  Train Acc:79.63% Test Loss:0.620856  Test Acc:78.25%  Learning Rate:0.100000	Time 03:20
# Epoch [  5/300]  Train Loss:0.515754  Train Acc:81.95% Test Loss:0.613112  Test Acc:78.48%  Learning Rate:0.100000	Time 03:08
# Epoch [  6/300]  Train Loss:0.464896  Train Acc:83.91% Test Loss:0.520222  Test Acc:82.20%  Learning Rate:0.100000	Time 03:06
# Epoch [  7/300]  Train Loss:0.424456  Train Acc:85.50% Test Loss:0.500663  Test Acc:82.54%  Learning Rate:0.100000	Time 03:04
# Epoch [  8/300]  Train Loss:0.398089  Train Acc:86.16% Test Loss:0.484700  Test Acc:83.49%  Learning Rate:0.100000	Time 03:07
# Epoch [  9/300]  Train Loss:0.372849  Train Acc:86.94% Test Loss:0.525966  Test Acc:82.55%  Learning Rate:0.100000	Time 03:10
# Epoch [ 10/300]  Train Loss:0.349867  Train Acc:87.83% Test Loss:0.474524  Test Acc:83.05%  Learning Rate:0.100000	Time 03:11
# Epoch [ 11/300]  Train Loss:0.332968  Train Acc:88.42% Test Loss:0.428894  Test Acc:85.16%  Learning Rate:0.100000	Time 03:06
# Epoch [ 12/300]  Train Loss:0.318199  Train Acc:88.98% Test Loss:0.399401  Test Acc:85.96%  Learning Rate:0.100000	Time 03:06
# Epoch [ 13/300]  Train Loss:0.301010  Train Acc:89.48% Test Loss:0.409382  Test Acc:86.00%  Learning Rate:0.100000	Time 03:11
# Epoch [ 14/300]  Train Loss:0.290929  Train Acc:89.79% Test Loss:0.416336  Test Acc:86.10%  Learning Rate:0.100000	Time 03:14
# Epoch [ 15/300]  Train Loss:0.278267  Train Acc:90.30% Test Loss:0.460956  Test Acc:84.45%  Learning Rate:0.100000	Time 03:13
# Epoch [ 16/300]  Train Loss:0.267652  Train Acc:90.62% Test Loss:0.459863  Test Acc:85.21%  Learning Rate:0.100000	Time 03:11
# Epoch [ 17/300]  Train Loss:0.263425  Train Acc:90.73% Test Loss:0.382354  Test Acc:86.96%  Learning Rate:0.100000	Time 03:10
# Epoch [ 18/300]  Train Loss:0.256436  Train Acc:90.96% Test Loss:0.427084  Test Acc:85.26%  Learning Rate:0.100000	Time 03:07
# Epoch [ 19/300]  Train Loss:0.248394  Train Acc:91.27% Test Loss:0.410510  Test Acc:86.69%  Learning Rate:0.100000	Time 03:10
# Epoch [ 20/300]  Train Loss:0.245935  Train Acc:91.38% Test Loss:0.390014  Test Acc:87.12%  Learning Rate:0.100000	Time 03:07
# Epoch [ 21/300]  Train Loss:0.235604  Train Acc:91.69% Test Loss:0.354320  Test Acc:87.90%  Learning Rate:0.100000	Time 03:12
# Epoch [ 22/300]  Train Loss:0.227480  Train Acc:92.01% Test Loss:0.401905  Test Acc:86.97%  Learning Rate:0.100000	Time 03:16
# Epoch [ 23/300]  Train Loss:0.224670  Train Acc:92.13% Test Loss:0.398948  Test Acc:86.40%  Learning Rate:0.100000	Time 03:58
# Epoch [ 24/300]  Train Loss:0.219289  Train Acc:92.34% Test Loss:0.354700  Test Acc:88.22%  Learning Rate:0.100000	Time 03:20
# Epoch [ 25/300]  Train Loss:0.221048  Train Acc:92.18% Test Loss:0.368682  Test Acc:87.83%  Learning Rate:0.100000	Time 03:13
# Epoch [ 26/300]  Train Loss:0.217762  Train Acc:92.39% Test Loss:0.385247  Test Acc:87.37%  Learning Rate:0.100000	Time 03:19
# Epoch [ 27/300]  Train Loss:0.210772  Train Acc:92.60% Test Loss:0.373476  Test Acc:87.34%  Learning Rate:0.100000	Time 03:22
# Epoch [ 28/300]  Train Loss:0.206693  Train Acc:92.80% Test Loss:0.392513  Test Acc:87.09%  Learning Rate:0.100000	Time 03:23
# Epoch [ 29/300]  Train Loss:0.209136  Train Acc:92.66% Test Loss:0.334081  Test Acc:88.80%  Learning Rate:0.100000	Time 03:22
# Epoch [ 30/300]  Train Loss:0.201351  Train Acc:92.90% Test Loss:0.357465  Test Acc:88.13%  Learning Rate:0.100000	Time 03:12
# Epoch [ 31/300]  Train Loss:0.192419  Train Acc:93.27% Test Loss:0.387867  Test Acc:87.40%  Learning Rate:0.100000	Time 03:08
# Epoch [ 32/300]  Train Loss:0.201653  Train Acc:92.98% Test Loss:0.344333  Test Acc:88.80%  Learning Rate:0.100000	Time 03:11
# Epoch [ 33/300]  Train Loss:0.198786  Train Acc:93.09% Test Loss:0.370450  Test Acc:87.31%  Learning Rate:0.100000	Time 03:41
# Epoch [ 34/300]  Train Loss:0.193735  Train Acc:93.16% Test Loss:0.421904  Test Acc:86.22%  Learning Rate:0.100000	Time 03:18
# Epoch [ 35/300]  Train Loss:0.190331  Train Acc:93.31% Test Loss:0.363270  Test Acc:88.54%  Learning Rate:0.100000	Time 03:21
# Epoch [ 36/300]  Train Loss:0.186515  Train Acc:93.35% Test Loss:0.414385  Test Acc:86.50%  Learning Rate:0.100000	Time 03:25
# Epoch [ 37/300]  Train Loss:0.187431  Train Acc:93.40% Test Loss:0.409757  Test Acc:87.01%  Learning Rate:0.100000	Time 03:24
# Epoch [ 38/300]  Train Loss:0.188122  Train Acc:93.31% Test Loss:0.374280  Test Acc:88.10%  Learning Rate:0.100000	Time 03:24
# Epoch [ 39/300]  Train Loss:0.180550  Train Acc:93.56% Test Loss:0.399577  Test Acc:87.60%  Learning Rate:0.100000	Time 03:08
# Epoch [ 40/300]  Train Loss:0.179237  Train Acc:93.72% Test Loss:0.372658  Test Acc:87.79%  Learning Rate:0.100000	Time 03:08
# Epoch [ 41/300]  Train Loss:0.176105  Train Acc:93.78% Test Loss:0.344669  Test Acc:88.98%  Learning Rate:0.100000	Time 03:29
# Epoch [ 42/300]  Train Loss:0.178846  Train Acc:93.72% Test Loss:0.371060  Test Acc:88.28%  Learning Rate:0.100000	Time 03:23
# Epoch [ 43/300]  Train Loss:0.178977  Train Acc:93.72% Test Loss:0.374544  Test Acc:87.39%  Learning Rate:0.100000	Time 03:23
# Epoch [ 44/300]  Train Loss:0.175833  Train Acc:93.83% Test Loss:0.363254  Test Acc:88.54%  Learning Rate:0.100000	Time 03:23
# Epoch [ 45/300]  Train Loss:0.174742  Train Acc:93.81% Test Loss:0.370298  Test Acc:88.63%  Learning Rate:0.100000	Time 03:18
# Epoch [ 46/300]  Train Loss:0.172613  Train Acc:93.93% Test Loss:0.336041  Test Acc:88.97%  Learning Rate:0.100000	Time 03:19
# Epoch [ 47/300]  Train Loss:0.173442  Train Acc:93.97% Test Loss:0.359307  Test Acc:88.83%  Learning Rate:0.100000	Time 03:18
# Epoch [ 48/300]  Train Loss:0.170136  Train Acc:93.95% Test Loss:0.355858  Test Acc:88.50%  Learning Rate:0.100000	Time 03:23
# Epoch [ 49/300]  Train Loss:0.169514  Train Acc:94.09% Test Loss:0.353203  Test Acc:88.40%  Learning Rate:0.100000	Time 03:13
# Epoch [ 50/300]  Train Loss:0.164370  Train Acc:94.21% Test Loss:0.371860  Test Acc:88.83%  Learning Rate:0.100000	Time 03:05
# Epoch [ 51/300]  Train Loss:0.165974  Train Acc:94.22% Test Loss:0.325752  Test Acc:89.49%  Learning Rate:0.100000	Time 03:10
# Epoch [ 52/300]  Train Loss:0.160309  Train Acc:94.32% Test Loss:0.398183  Test Acc:87.81%  Learning Rate:0.100000	Time 03:10
# Epoch [ 53/300]  Train Loss:0.170013  Train Acc:93.89% Test Loss:0.364222  Test Acc:88.02%  Learning Rate:0.100000	Time 03:09
# Epoch [ 54/300]  Train Loss:0.164393  Train Acc:94.18% Test Loss:0.344712  Test Acc:88.81%  Learning Rate:0.100000	Time 03:12
# Epoch [ 55/300]  Train Loss:0.162137  Train Acc:94.27% Test Loss:0.362366  Test Acc:88.34%  Learning Rate:0.100000	Time 03:17
# Epoch [ 56/300]  Train Loss:0.158607  Train Acc:94.31% Test Loss:0.352558  Test Acc:89.06%  Learning Rate:0.100000	Time 03:08
# Epoch [ 57/300]  Train Loss:0.166362  Train Acc:94.14% Test Loss:0.374739  Test Acc:88.56%  Learning Rate:0.100000	Time 03:18
# Epoch [ 58/300]  Train Loss:0.161284  Train Acc:94.30% Test Loss:0.336825  Test Acc:88.85%  Learning Rate:0.100000	Time 03:22
# Epoch [ 59/300]  Train Loss:0.160139  Train Acc:94.30% Test Loss:0.336487  Test Acc:89.20%  Learning Rate:0.100000	Time 03:19
# Epoch [ 60/300]  Train Loss:0.157726  Train Acc:94.53% Test Loss:0.333267  Test Acc:89.69%  Learning Rate:0.100000	Time 03:13
# Epoch [ 61/300]  Train Loss:0.161053  Train Acc:94.33% Test Loss:0.345095  Test Acc:88.93%  Learning Rate:0.100000	Time 03:21
# Epoch [ 62/300]  Train Loss:0.152330  Train Acc:94.74% Test Loss:0.384944  Test Acc:88.13%  Learning Rate:0.100000	Time 03:11
# Epoch [ 63/300]  Train Loss:0.156306  Train Acc:94.59% Test Loss:0.350673  Test Acc:88.87%  Learning Rate:0.100000	Time 03:16
# Epoch [ 64/300]  Train Loss:0.152685  Train Acc:94.62% Test Loss:0.349796  Test Acc:88.90%  Learning Rate:0.100000	Time 03:07
# Epoch [ 65/300]  Train Loss:0.157829  Train Acc:94.35% Test Loss:0.358939  Test Acc:89.16%  Learning Rate:0.100000	Time 03:09
# Epoch [ 66/300]  Train Loss:0.154505  Train Acc:94.53% Test Loss:0.337073  Test Acc:89.33%  Learning Rate:0.100000	Time 03:08
# Epoch [ 67/300]  Train Loss:0.153030  Train Acc:94.61% Test Loss:0.348513  Test Acc:89.18%  Learning Rate:0.100000	Time 03:08
# Epoch [ 68/300]  Train Loss:0.154642  Train Acc:94.55% Test Loss:0.342413  Test Acc:89.25%  Learning Rate:0.100000	Time 03:10
# Epoch [ 69/300]  Train Loss:0.151423  Train Acc:94.66% Test Loss:0.365003  Test Acc:89.04%  Learning Rate:0.100000	Time 03:11
# Epoch [ 70/300]  Train Loss:0.146890  Train Acc:94.88% Test Loss:0.363577  Test Acc:89.30%  Learning Rate:0.100000	Time 03:10
# Epoch [ 71/300]  Train Loss:0.151986  Train Acc:94.55% Test Loss:0.404377  Test Acc:87.64%  Learning Rate:0.100000	Time 03:08
# Epoch [ 72/300]  Train Loss:0.156023  Train Acc:94.40% Test Loss:0.333835  Test Acc:89.64%  Learning Rate:0.100000	Time 03:09
# Epoch [ 73/300]  Train Loss:0.146847  Train Acc:94.84% Test Loss:0.378512  Test Acc:87.92%  Learning Rate:0.100000	Time 03:06
# Epoch [ 74/300]  Train Loss:0.151762  Train Acc:94.52% Test Loss:0.328492  Test Acc:89.69%  Learning Rate:0.100000	Time 03:05
# Epoch [ 75/300]  Train Loss:0.145105  Train Acc:94.84% Test Loss:0.336194  Test Acc:89.44%  Learning Rate:0.100000	Time 03:06
# Epoch [ 76/300]  Train Loss:0.148423  Train Acc:94.84% Test Loss:0.338140  Test Acc:89.73%  Learning Rate:0.100000	Time 03:03
# Epoch [ 77/300]  Train Loss:0.146066  Train Acc:94.85% Test Loss:0.328503  Test Acc:89.50%  Learning Rate:0.100000	Time 03:03
# Epoch [ 78/300]  Train Loss:0.143840  Train Acc:94.89% Test Loss:0.308504  Test Acc:90.02%  Learning Rate:0.100000	Time 03:06
# Epoch [ 79/300]  Train Loss:0.145972  Train Acc:94.82% Test Loss:0.358437  Test Acc:88.82%  Learning Rate:0.100000	Time 03:04
# Epoch [ 80/300]  Train Loss:0.142803  Train Acc:94.95% Test Loss:0.323669  Test Acc:89.60%  Learning Rate:0.100000	Time 03:05
# Epoch [ 81/300]  Train Loss:0.141138  Train Acc:95.16% Test Loss:0.318606  Test Acc:89.70%  Learning Rate:0.100000	Time 03:04
# Epoch [ 82/300]  Train Loss:0.143328  Train Acc:95.03% Test Loss:0.353693  Test Acc:88.64%  Learning Rate:0.100000	Time 03:02
# Epoch [ 83/300]  Train Loss:0.144837  Train Acc:94.89% Test Loss:0.358101  Test Acc:88.52%  Learning Rate:0.100000	Time 03:04
# Epoch [ 84/300]  Train Loss:0.142627  Train Acc:94.98% Test Loss:0.362307  Test Acc:88.83%  Learning Rate:0.100000	Time 03:05
# Epoch [ 85/300]  Train Loss:0.144153  Train Acc:94.95% Test Loss:0.338637  Test Acc:89.49%  Learning Rate:0.100000	Time 03:06
# Epoch [ 86/300]  Train Loss:0.141396  Train Acc:95.01% Test Loss:0.328478  Test Acc:89.65%  Learning Rate:0.100000	Time 03:09
# Epoch [ 87/300]  Train Loss:0.144304  Train Acc:94.95% Test Loss:0.301489  Test Acc:90.23%  Learning Rate:0.100000	Time 03:10
# Epoch [ 88/300]  Train Loss:0.138556  Train Acc:95.17% Test Loss:0.341741  Test Acc:89.73%  Learning Rate:0.100000	Time 03:06
# Epoch [ 89/300]  Train Loss:0.139210  Train Acc:95.06% Test Loss:0.340071  Test Acc:89.29%  Learning Rate:0.100000	Time 03:04
# Epoch [ 90/300]  Train Loss:0.142408  Train Acc:94.95% Test Loss:0.312745  Test Acc:90.13%  Learning Rate:0.100000	Time 03:06
# Epoch [ 91/300]  Train Loss:0.139584  Train Acc:95.13% Test Loss:0.316159  Test Acc:89.91%  Learning Rate:0.100000	Time 03:12
# Epoch [ 92/300]  Train Loss:0.139265  Train Acc:95.09% Test Loss:0.376726  Test Acc:87.94%  Learning Rate:0.100000	Time 03:10
# Epoch [ 93/300]  Train Loss:0.138172  Train Acc:95.06% Test Loss:0.336486  Test Acc:89.64%  Learning Rate:0.100000	Time 03:08
# Epoch [ 94/300]  Train Loss:0.141214  Train Acc:95.05% Test Loss:0.345153  Test Acc:89.13%  Learning Rate:0.100000	Time 03:12
# Epoch [ 95/300]  Train Loss:0.133365  Train Acc:95.26% Test Loss:0.414276  Test Acc:88.06%  Learning Rate:0.100000	Time 03:19
# Epoch [ 96/300]  Train Loss:0.135028  Train Acc:95.31% Test Loss:0.363332  Test Acc:88.83%  Learning Rate:0.100000	Time 03:09
# Epoch [ 97/300]  Train Loss:0.140936  Train Acc:94.98% Test Loss:0.344309  Test Acc:89.14%  Learning Rate:0.100000	Time 03:06
# Epoch [ 98/300]  Train Loss:0.138871  Train Acc:95.14% Test Loss:0.340019  Test Acc:89.34%  Learning Rate:0.100000	Time 03:07
# Epoch [ 99/300]  Train Loss:0.135394  Train Acc:95.20% Test Loss:0.320365  Test Acc:90.07%  Learning Rate:0.100000	Time 03:11
# Epoch [100/300]  Train Loss:0.136730  Train Acc:95.21% Test Loss:0.363778  Test Acc:89.01%  Learning Rate:0.100000	Time 03:10
# Epoch [101/300]  Train Loss:0.139592  Train Acc:95.07% Test Loss:0.319641  Test Acc:89.78%  Learning Rate:0.100000	Time 03:13
# Epoch [102/300]  Train Loss:0.132023  Train Acc:95.29% Test Loss:0.342308  Test Acc:89.32%  Learning Rate:0.100000	Time 03:12
# Epoch [103/300]  Train Loss:0.141533  Train Acc:94.96% Test Loss:0.406534  Test Acc:87.28%  Learning Rate:0.100000	Time 03:04
# Epoch [104/300]  Train Loss:0.132678  Train Acc:95.37% Test Loss:0.325700  Test Acc:89.94%  Learning Rate:0.100000	Time 03:10
# Epoch [105/300]  Train Loss:0.126344  Train Acc:95.48% Test Loss:0.400486  Test Acc:87.93%  Learning Rate:0.100000	Time 03:08
# Epoch [106/300]  Train Loss:0.133432  Train Acc:95.30% Test Loss:0.305161  Test Acc:89.94%  Learning Rate:0.100000	Time 03:04
# Epoch [107/300]  Train Loss:0.134345  Train Acc:95.28% Test Loss:0.313201  Test Acc:89.82%  Learning Rate:0.100000	Time 03:03
# Epoch [108/300]  Train Loss:0.130970  Train Acc:95.40% Test Loss:0.365318  Test Acc:89.30%  Learning Rate:0.100000	Time 03:10
# Epoch [109/300]  Train Loss:0.128890  Train Acc:95.45% Test Loss:0.353076  Test Acc:89.60%  Learning Rate:0.100000	Time 03:20
# Epoch [110/300]  Train Loss:0.134338  Train Acc:95.24% Test Loss:0.356175  Test Acc:88.97%  Learning Rate:0.100000	Time 03:14
# Epoch [111/300]  Train Loss:0.130758  Train Acc:95.38% Test Loss:0.328439  Test Acc:89.96%  Learning Rate:0.100000	Time 03:11
# Epoch [112/300]  Train Loss:0.136392  Train Acc:95.12% Test Loss:0.368216  Test Acc:89.29%  Learning Rate:0.100000	Time 03:16
# Epoch [113/300]  Train Loss:0.127475  Train Acc:95.60% Test Loss:0.339462  Test Acc:89.47%  Learning Rate:0.100000	Time 03:17
# Epoch [114/300]  Train Loss:0.134067  Train Acc:95.28% Test Loss:0.343857  Test Acc:89.57%  Learning Rate:0.100000	Time 03:11
# Epoch [115/300]  Train Loss:0.125646  Train Acc:95.62% Test Loss:0.338071  Test Acc:89.59%  Learning Rate:0.100000	Time 03:04
# Epoch [116/300]  Train Loss:0.127620  Train Acc:95.51% Test Loss:0.302569  Test Acc:90.62%  Learning Rate:0.100000	Time 03:14
# Epoch [117/300]  Train Loss:0.125208  Train Acc:95.67% Test Loss:0.316314  Test Acc:90.32%  Learning Rate:0.100000	Time 03:14
# Epoch [118/300]  Train Loss:0.129730  Train Acc:95.46% Test Loss:0.338390  Test Acc:89.46%  Learning Rate:0.100000	Time 03:08
# Epoch [119/300]  Train Loss:0.127341  Train Acc:95.45% Test Loss:0.349965  Test Acc:89.68%  Learning Rate:0.100000	Time 03:12
# Epoch [120/300]  Train Loss:0.132369  Train Acc:95.25% Test Loss:0.323566  Test Acc:89.90%  Learning Rate:0.100000	Time 03:17
# Epoch [121/300]  Train Loss:0.131501  Train Acc:95.36% Test Loss:0.312987  Test Acc:90.19%  Learning Rate:0.100000	Time 03:07
# Epoch [122/300]  Train Loss:0.131389  Train Acc:95.40% Test Loss:0.320383  Test Acc:89.69%  Learning Rate:0.100000	Time 03:20
# Epoch [123/300]  Train Loss:0.126509  Train Acc:95.61% Test Loss:0.317243  Test Acc:90.10%  Learning Rate:0.100000	Time 03:06
# Epoch [124/300]  Train Loss:0.126439  Train Acc:95.57% Test Loss:0.346059  Test Acc:89.21%  Learning Rate:0.100000	Time 03:19
# Epoch [125/300]  Train Loss:0.126382  Train Acc:95.54% Test Loss:0.333716  Test Acc:89.63%  Learning Rate:0.100000	Time 03:24
# Epoch [126/300]  Train Loss:0.127721  Train Acc:95.52% Test Loss:0.392477  Test Acc:88.79%  Learning Rate:0.100000	Time 03:25
# Epoch [127/300]  Train Loss:0.123526  Train Acc:95.62% Test Loss:0.316817  Test Acc:90.23%  Learning Rate:0.100000	Time 03:07
# Epoch [128/300]  Train Loss:0.130322  Train Acc:95.33% Test Loss:0.311102  Test Acc:90.22%  Learning Rate:0.100000	Time 03:06
# Epoch [129/300]  Train Loss:0.124833  Train Acc:95.68% Test Loss:0.343925  Test Acc:89.14%  Learning Rate:0.100000	Time 03:22
# Epoch [130/300]  Train Loss:0.125695  Train Acc:95.57% Test Loss:0.429571  Test Acc:88.14%  Learning Rate:0.100000	Time 03:10
# Epoch [131/300]  Train Loss:0.122837  Train Acc:95.71% Test Loss:0.306854  Test Acc:90.53%  Learning Rate:0.100000	Time 03:08
# Epoch [132/300]  Train Loss:0.122917  Train Acc:95.71% Test Loss:0.281244  Test Acc:90.81%  Learning Rate:0.100000	Time 03:24
# Epoch [133/300]  Train Loss:0.128052  Train Acc:95.52% Test Loss:0.322590  Test Acc:89.37%  Learning Rate:0.100000	Time 03:09
# Epoch [134/300]  Train Loss:0.124812  Train Acc:95.64% Test Loss:0.354566  Test Acc:89.49%  Learning Rate:0.100000	Time 03:04
# Epoch [135/300]  Train Loss:0.121728  Train Acc:95.68% Test Loss:0.331988  Test Acc:90.17%  Learning Rate:0.100000	Time 03:17
# Epoch [136/300]  Train Loss:0.126774  Train Acc:95.60% Test Loss:0.371582  Test Acc:88.86%  Learning Rate:0.100000	Time 03:15
# Epoch [137/300]  Train Loss:0.125966  Train Acc:95.54% Test Loss:0.377577  Test Acc:88.65%  Learning Rate:0.100000	Time 03:07
# Epoch [138/300]  Train Loss:0.122072  Train Acc:95.75% Test Loss:0.345065  Test Acc:89.42%  Learning Rate:0.100000	Time 03:04
# Epoch [139/300]  Train Loss:0.122206  Train Acc:95.69% Test Loss:0.318307  Test Acc:90.03%  Learning Rate:0.100000	Time 03:02
# Epoch [140/300]  Train Loss:0.125487  Train Acc:95.60% Test Loss:0.355679  Test Acc:89.42%  Learning Rate:0.100000	Time 03:04
# Epoch [141/300]  Train Loss:0.119915  Train Acc:95.73% Test Loss:0.382431  Test Acc:88.63%  Learning Rate:0.100000	Time 03:03
# Epoch [142/300]  Train Loss:0.125254  Train Acc:95.57% Test Loss:0.315508  Test Acc:90.52%  Learning Rate:0.100000	Time 03:05
# Epoch [143/300]  Train Loss:0.123041  Train Acc:95.67% Test Loss:0.336163  Test Acc:89.63%  Learning Rate:0.100000	Time 03:03
# Epoch [144/300]  Train Loss:0.122814  Train Acc:95.69% Test Loss:0.360701  Test Acc:89.28%  Learning Rate:0.100000	Time 03:05
# Epoch [145/300]  Train Loss:0.122658  Train Acc:95.65% Test Loss:0.312399  Test Acc:90.26%  Learning Rate:0.100000	Time 03:05
# Epoch [146/300]  Train Loss:0.119502  Train Acc:95.79% Test Loss:0.328512  Test Acc:89.83%  Learning Rate:0.100000	Time 03:06
# Epoch [147/300]  Train Loss:0.123822  Train Acc:95.65% Test Loss:0.324869  Test Acc:90.13%  Learning Rate:0.100000	Time 03:04
# Epoch [148/300]  Train Loss:0.116684  Train Acc:95.96% Test Loss:0.302219  Test Acc:90.50%  Learning Rate:0.100000	Time 03:05
# Epoch [149/300]  Train Loss:0.122869  Train Acc:95.64% Test Loss:0.353867  Test Acc:89.69%  Learning Rate:0.100000	Time 03:02
# Epoch [150/300]  Train Loss:0.121372  Train Acc:95.84% Test Loss:0.335630  Test Acc:89.81%  Learning Rate:0.100000	Time 03:04
# Epoch [172/300]  Train Loss:0.005934  Train Acc:99.86% Test Loss:0.226830  Test Acc:94.21%  Learning Rate:0.010000	Time 03:03
# Epoch [173/300]  Train Loss:0.005435  Train Acc:99.89% Test Loss:0.229624  Test Acc:94.07%  Learning Rate:0.010000	Time 03:03
# Epoch [174/300]  Train Loss:0.005170  Train Acc:99.89% Test Loss:0.238195  Test Acc:94.28%  Learning Rate:0.010000	Time 03:07
# Epoch [175/300]  Train Loss:0.004598  Train Acc:99.90% Test Loss:0.238142  Test Acc:94.15%  Learning Rate:0.010000	Time 03:04
# Epoch [176/300]  Train Loss:0.004533  Train Acc:99.92% Test Loss:0.242043  Test Acc:94.30%  Learning Rate:0.010000	Time 03:03
# Epoch [177/300]  Train Loss:0.004199  Train Acc:99.93% Test Loss:0.233623  Test Acc:94.20%  Learning Rate:0.010000	Time 03:04
# Epoch [178/300]  Train Loss:0.004472  Train Acc:99.90% Test Loss:0.239745  Test Acc:94.34%  Learning Rate:0.010000	Time 03:04
# Epoch [179/300]  Train Loss:0.004212  Train Acc:99.89% Test Loss:0.231882  Test Acc:94.39%  Learning Rate:0.010000	Time 03:05
# Epoch [180/300]  Train Loss:0.004190  Train Acc:99.93% Test Loss:0.248356  Test Acc:94.37%  Learning Rate:0.010000	Time 03:02
# Epoch [181/300]  Train Loss:0.004010  Train Acc:99.92% Test Loss:0.242248  Test Acc:94.28%  Learning Rate:0.010000	Time 03:05
# Epoch [182/300]  Train Loss:0.004008  Train Acc:99.91% Test Loss:0.237974  Test Acc:94.06%  Learning Rate:0.010000	Time 03:03
# Epoch [183/300]  Train Loss:0.003915  Train Acc:99.93% Test Loss:0.230299  Test Acc:94.45%  Learning Rate:0.010000	Time 03:05
# Epoch [184/300]  Train Loss:0.003425  Train Acc:99.95% Test Loss:0.240175  Test Acc:94.08%  Learning Rate:0.010000	Time 03:05
# Epoch [185/300]  Train Loss:0.003724  Train Acc:99.93% Test Loss:0.242897  Test Acc:94.27%  Learning Rate:0.010000	Time 03:04
# Epoch [186/300]  Train Loss:0.003202  Train Acc:99.95% Test Loss:0.225083  Test Acc:94.47%  Learning Rate:0.010000	Time 03:03
# Epoch [187/300]  Train Loss:0.003391  Train Acc:99.93% Test Loss:0.246044  Test Acc:94.58%  Learning Rate:0.010000	Time 03:06
# Epoch [188/300]  Train Loss:0.003117  Train Acc:99.95% Test Loss:0.245683  Test Acc:94.61%  Learning Rate:0.010000	Time 03:03
# Epoch [189/300]  Train Loss:0.003261  Train Acc:99.94% Test Loss:0.244534  Test Acc:94.34%  Learning Rate:0.010000	Time 03:03
# Epoch [190/300]  Train Loss:0.003162  Train Acc:99.94% Test Loss:0.256357  Test Acc:94.20%  Learning Rate:0.010000	Time 03:05
# Epoch [191/300]  Train Loss:0.003294  Train Acc:99.94% Test Loss:0.238001  Test Acc:94.13%  Learning Rate:0.010000	Time 03:01
# Epoch [192/300]  Train Loss:0.003066  Train Acc:99.95% Test Loss:0.239533  Test Acc:94.44%  Learning Rate:0.010000	Time 03:03
# Epoch [215/300]  Train Loss:0.002556  Train Acc:99.96% Test Loss:0.239154  Test Acc:94.42%  Learning Rate:0.010000	Time 03:02
# Epoch [216/300]  Train Loss:0.002263  Train Acc:99.96% Test Loss:0.247683  Test Acc:94.47%  Learning Rate:0.010000	Time 03:05
# Epoch [217/300]  Train Loss:0.001854  Train Acc:99.98% Test Loss:0.259297  Test Acc:94.23%  Learning Rate:0.010000	Time 03:06
# Epoch [218/300]  Train Loss:0.002456  Train Acc:99.95% Test Loss:0.239089  Test Acc:94.50%  Learning Rate:0.010000	Time 03:04
# Epoch [219/300]  Train Loss:0.002404  Train Acc:99.95% Test Loss:0.240732  Test Acc:94.50%  Learning Rate:0.010000	Time 03:04
# Epoch [220/300]  Train Loss:0.002561  Train Acc:99.95% Test Loss:0.250560  Test Acc:94.56%  Learning Rate:0.010000	Time 03:03
# Epoch [221/300]  Train Loss:0.002490  Train Acc:99.95% Test Loss:0.255156  Test Acc:94.34%  Learning Rate:0.010000	Time 03:03
# Epoch [222/300]  Train Loss:0.001925  Train Acc:99.98% Test Loss:0.261802  Test Acc:94.31%  Learning Rate:0.010000	Time 03:04
# Epoch [223/300]  Train Loss:0.002443  Train Acc:99.95% Test Loss:0.249152  Test Acc:94.36%  Learning Rate:0.010000	Time 03:06
# Epoch [224/300]  Train Loss:0.001846  Train Acc:99.98% Test Loss:0.262036  Test Acc:94.21%  Learning Rate:0.010000	Time 03:04
# Epoch [225/300]  Train Loss:0.002137  Train Acc:99.97% Test Loss:0.241556  Test Acc:94.57%  Learning Rate:0.010000	Time 03:04
# Epoch [226/300]  Train Loss:0.002228  Train Acc:99.96% Test Loss:0.251728  Test Acc:94.30%  Learning Rate:0.001000	Time 03:05
# Epoch [227/300]  Train Loss:0.001607  Train Acc:99.98% Test Loss:0.237333  Test Acc:94.76%  Learning Rate:0.001000	Time 03:04
# Epoch [228/300]  Train Loss:0.001702  Train Acc:99.97% Test Loss:0.252912  Test Acc:94.54%  Learning Rate:0.001000	Time 03:02
# Epoch [229/300]  Train Loss:0.001757  Train Acc:99.98% Test Loss:0.252078  Test Acc:94.21%  Learning Rate:0.001000	Time 03:04
# Epoch [230/300]  Train Loss:0.001764  Train Acc:99.97% Test Loss:0.257452  Test Acc:94.53%  Learning Rate:0.001000	Time 03:04
# Epoch [231/300]  Train Loss:0.001646  Train Acc:99.98% Test Loss:0.247980  Test Acc:94.40%  Learning Rate:0.001000	Time 03:03
# Epoch [232/300]  Train Loss:0.001657  Train Acc:99.98% Test Loss:0.245028  Test Acc:94.46%  Learning Rate:0.001000	Time 03:06
# Epoch [233/300]  Train Loss:0.001496  Train Acc:99.98% Test Loss:0.258243  Test Acc:94.40%  Learning Rate:0.001000	Time 03:03
# Epoch [234/300]  Train Loss:0.001414  Train Acc:99.99% Test Loss:0.249339  Test Acc:94.49%  Learning Rate:0.001000	Time 03:02
# Epoch [235/300]  Train Loss:0.001719  Train Acc:99.98% Test Loss:0.255148  Test Acc:94.21%  Learning Rate:0.001000	Time 03:05
# Epoch [236/300]  Train Loss:0.001508  Train Acc:99.98% Test Loss:0.256893  Test Acc:94.37%  Learning Rate:0.001000	Time 03:02
# Epoch [237/300]  Train Loss:0.001574  Train Acc:99.98% Test Loss:0.258165  Test Acc:94.22%  Learning Rate:0.001000	Time 03:04
# Epoch [238/300]  Train Loss:0.001720  Train Acc:99.96% Test Loss:0.257500  Test Acc:94.21%  Learning Rate:0.001000	Time 03:02
# Epoch [239/300]  Train Loss:0.001317  Train Acc:99.99% Test Loss:0.256947  Test Acc:94.37%  Learning Rate:0.001000	Time 03:05
# Epoch [240/300]  Train Loss:0.001379  Train Acc:99.99% Test Loss:0.257444  Test Acc:94.39%  Learning Rate:0.001000	Time 03:04
# Epoch [241/300]  Train Loss:0.001304  Train Acc:99.99% Test Loss:0.243611  Test Acc:94.35%  Learning Rate:0.001000	Time 03:04
# Epoch [242/300]  Train Loss:0.001336  Train Acc:99.99% Test Loss:0.241022  Test Acc:94.50%  Learning Rate:0.001000	Time 03:04
# Epoch [243/300]  Train Loss:0.001384  Train Acc:99.98% Test Loss:0.253431  Test Acc:94.34%  Learning Rate:0.001000	Time 03:04
# Epoch [244/300]  Train Loss:0.001506  Train Acc:99.98% Test Loss:0.248823  Test Acc:94.43%  Learning Rate:0.001000	Time 03:04
# Epoch [245/300]  Train Loss:0.001500  Train Acc:99.99% Test Loss:0.258270  Test Acc:94.36%  Learning Rate:0.001000	Time 03:04
# Epoch [246/300]  Train Loss:0.001486  Train Acc:99.99% Test Loss:0.263690  Test Acc:94.00%  Learning Rate:0.001000	Time 03:04
# Epoch [247/300]  Train Loss:0.001426  Train Acc:99.98% Test Loss:0.244909  Test Acc:94.68%  Learning Rate:0.001000	Time 03:03
# Epoch [248/300]  Train Loss:0.001487  Train Acc:99.98% Test Loss:0.237440  Test Acc:94.58%  Learning Rate:0.001000	Time 03:04
# Epoch [249/300]  Train Loss:0.001342  Train Acc:99.99% Test Loss:0.255689  Test Acc:94.41%  Learning Rate:0.001000	Time 03:03
# Epoch [250/300]  Train Loss:0.001374  Train Acc:99.99% Test Loss:0.242907  Test Acc:94.44%  Learning Rate:0.001000	Time 03:04
# Epoch [251/300]  Train Loss:0.001543  Train Acc:99.98% Test Loss:0.245053  Test Acc:94.57%  Learning Rate:0.001000	Time 03:05
# Epoch [252/300]  Train Loss:0.001506  Train Acc:99.98% Test Loss:0.245206  Test Acc:94.43%  Learning Rate:0.001000	Time 03:05
# Epoch [253/300]  Train Loss:0.001371  Train Acc:99.99% Test Loss:0.249122  Test Acc:94.45%  Learning Rate:0.001000	Time 03:05
# Epoch [254/300]  Train Loss:0.001367  Train Acc:99.98% Test Loss:0.251223  Test Acc:94.33%  Learning Rate:0.001000	Time 03:03
# Epoch [255/300]  Train Loss:0.001280  Train Acc:99.99% Test Loss:0.253883  Test Acc:94.63%  Learning Rate:0.001000	Time 03:03
# Epoch [256/300]  Train Loss:0.001274  Train Acc:99.99% Test Loss:0.237314  Test Acc:94.61%  Learning Rate:0.001000	Time 03:04
# Epoch [257/300]  Train Loss:0.001226  Train Acc:99.99% Test Loss:0.253099  Test Acc:94.58%  Learning Rate:0.001000	Time 03:01
# Epoch [258/300]  Train Loss:0.001334  Train Acc:99.98% Test Loss:0.249591  Test Acc:94.55%  Learning Rate:0.001000	Time 03:03
# Epoch [259/300]  Train Loss:0.001284  Train Acc:99.99% Test Loss:0.251800  Test Acc:94.42%  Learning Rate:0.001000	Time 03:02
# Epoch [260/300]  Train Loss:0.001437  Train Acc:99.98% Test Loss:0.254528  Test Acc:94.48%  Learning Rate:0.001000	Time 03:24
# Epoch [261/300]  Train Loss:0.001292  Train Acc:99.99% Test Loss:0.245345  Test Acc:94.46%  Learning Rate:0.001000	Time 04:28
# Epoch [262/300]  Train Loss:0.001300  Train Acc:99.99% Test Loss:0.243246  Test Acc:94.52%  Learning Rate:0.001000	Time 04:27
# Epoch [263/300]  Train Loss:0.001353  Train Acc:99.98% Test Loss:0.245118  Test Acc:94.70%  Learning Rate:0.001000	Time 04:27
# Epoch [264/300]  Train Loss:0.001322  Train Acc:99.98% Test Loss:0.244822  Test Acc:94.43%  Learning Rate:0.001000	Time 04:22
# Epoch [265/300]  Train Loss:0.001256  Train Acc:99.99% Test Loss:0.245534  Test Acc:94.44%  Learning Rate:0.001000	Time 04:23
# Epoch [266/300]  Train Loss:0.001250  Train Acc:99.98% Test Loss:0.245596  Test Acc:94.41%  Learning Rate:0.001000	Time 04:30
# Epoch [267/300]  Train Loss:0.001286  Train Acc:99.99% Test Loss:0.235971  Test Acc:94.64%  Learning Rate:0.001000	Time 04:24
# Epoch [268/300]  Train Loss:0.001185  Train Acc:99.99% Test Loss:0.250497  Test Acc:94.62%  Learning Rate:0.001000	Time 04:30
# Epoch [269/300]  Train Loss:0.001130  Train Acc:99.99% Test Loss:0.258433  Test Acc:94.39%  Learning Rate:0.001000	Time 04:34
# Epoch [270/300]  Train Loss:0.001324  Train Acc:99.99% Test Loss:0.266142  Test Acc:94.29%  Learning Rate:0.001000	Time 04:27
# Epoch [271/300]  Train Loss:0.001390  Train Acc:99.98% Test Loss:0.264085  Test Acc:94.13%  Learning Rate:0.001000	Time 04:20
# Epoch [272/300]  Train Loss:0.001212  Train Acc:99.98% Test Loss:0.252700  Test Acc:94.31%  Learning Rate:0.001000	Time 04:25
# Epoch [273/300]  Train Loss:0.001321  Train Acc:99.98% Test Loss:0.253752  Test Acc:94.55%  Learning Rate:0.001000	Time 04:25
# Epoch [274/300]  Train Loss:0.001323  Train Acc:99.98% Test Loss:0.244347  Test Acc:94.47%  Learning Rate:0.001000	Time 04:25
# Epoch [275/300]  Train Loss:0.001222  Train Acc:99.98% Test Loss:0.243140  Test Acc:94.62%  Learning Rate:0.001000	Time 04:35
# Epoch [276/300]  Train Loss:0.001324  Train Acc:99.98% Test Loss:0.257915  Test Acc:94.46%  Learning Rate:0.001000	Time 04:21
# Epoch [277/300]  Train Loss:0.001124  Train Acc:100.00% Test Loss:0.248354  Test Acc:94.54%  Learning Rate:0.001000	Time 04:26
# Epoch [278/300]  Train Loss:0.001224  Train Acc:99.99% Test Loss:0.245695  Test Acc:94.53%  Learning Rate:0.001000	Time 04:26
# Epoch [279/300]  Train Loss:0.001220  Train Acc:99.99% Test Loss:0.246593  Test Acc:94.57%  Learning Rate:0.001000	Time 04:30
# Epoch [280/300]  Train Loss:0.001235  Train Acc:99.99% Test Loss:0.251975  Test Acc:94.49%  Learning Rate:0.001000	Time 04:23
# Epoch [281/300]  Train Loss:0.001424  Train Acc:99.98% Test Loss:0.255511  Test Acc:94.24%  Learning Rate:0.001000	Time 04:30
# Epoch [282/300]  Train Loss:0.001225  Train Acc:99.99% Test Loss:0.251720  Test Acc:94.35%  Learning Rate:0.001000	Time 04:27
# Epoch [283/300]  Train Loss:0.001167  Train Acc:99.99% Test Loss:0.251225  Test Acc:94.44%  Learning Rate:0.001000	Time 04:39
# Epoch [284/300]  Train Loss:0.001186  Train Acc:99.98% Test Loss:0.249869  Test Acc:94.76%  Learning Rate:0.001000	Time 04:27
# Epoch [285/300]  Train Loss:0.001379  Train Acc:99.98% Test Loss:0.242944  Test Acc:94.46%  Learning Rate:0.001000	Time 03:28
# Epoch [286/300]  Train Loss:0.001177  Train Acc:99.99% Test Loss:0.248459  Test Acc:94.56%  Learning Rate:0.001000	Time 03:21
# Epoch [287/300]  Train Loss:0.001188  Train Acc:99.99% Test Loss:0.243412  Test Acc:94.70%  Learning Rate:0.001000	Time 03:08
# Epoch [288/300]  Train Loss:0.001163  Train Acc:99.99% Test Loss:0.240958  Test Acc:94.60%  Learning Rate:0.001000	Time 03:09
# Epoch [289/300]  Train Loss:0.001155  Train Acc:99.99% Test Loss:0.254028  Test Acc:94.46%  Learning Rate:0.001000	Time 03:13
# Epoch [290/300]  Train Loss:0.001055  Train Acc:100.00% Test Loss:0.241838  Test Acc:94.43%  Learning Rate:0.001000	Time 03:12
# Epoch [291/300]  Train Loss:0.001136  Train Acc:99.99% Test Loss:0.252443  Test Acc:94.65%  Learning Rate:0.001000	Time 03:07
# Epoch [292/300]  Train Loss:0.001291  Train Acc:99.99% Test Loss:0.250705  Test Acc:94.50%  Learning Rate:0.001000	Time 03:13
# Epoch [293/300]  Train Loss:0.001063  Train Acc:100.00% Test Loss:0.247170  Test Acc:94.61%  Learning Rate:0.001000	Time 03:13
# Epoch [294/300]  Train Loss:0.001236  Train Acc:99.99% Test Loss:0.255536  Test Acc:94.45%  Learning Rate:0.001000	Time 03:06
# Epoch [295/300]  Train Loss:0.001069  Train Acc:99.99% Test Loss:0.257219  Test Acc:94.59%  Learning Rate:0.001000	Time 03:10
# Epoch [296/300]  Train Loss:0.001295  Train Acc:99.99% Test Loss:0.253697  Test Acc:94.58%  Learning Rate:0.001000	Time 03:34
# Epoch [297/300]  Train Loss:0.001138  Train Acc:99.99% Test Loss:0.244014  Test Acc:94.65%  Learning Rate:0.001000	Time 03:05
# Epoch [298/300]  Train Loss:0.001091  Train Acc:99.99% Test Loss:0.237460  Test Acc:94.50%  Learning Rate:0.001000	Time 03:05
# Epoch [299/300]  Train Loss:0.001196  Train Acc:99.99% Test Loss:0.257681  Test Acc:94.21%  Learning Rate:0.001000	Time 03:05
# Epoch [300/300]  Train Loss:0.001107  Train Acc:99.99% Test Loss:0.250565  Test Acc:94.63%  Learning Rate:0.001000	Time 03:06

# %%
plot_history(epoch ,Acc, Loss, Lr)

# %% [markdown]
# ### 7.测试

# %%
correct = 0   # 定义预测正确的图片数，初始化为0
total = 0     # 总共参与测试的图片数，也初始化为0
# testloader = torch.utils.data.DataLoader(testset, batch_size=32,shuffle=True, num_workers=2)
torch.cuda.empty_cache()
net.eval()
with torch.no_grad():
    for data in testloader:  # 循环每一个batch
        images, labels = data
        images = images.to(device)
        labels = labels.to(device)
        net.eval()  # 把模型转为test模式
        if hasattr(torch.cuda, 'empty_cache'):
            torch.cuda.empty_cache()
        outputs = net(images)  # 输入网络进行测试

        # outputs.data是一个4x10张量，将每一行的最大的那一列的值和序号各自组成一个一维张量返回，第一个是值的张量，第二个是序号的张量。
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)          # 更新测试图片的数量
        correct += (predicted == labels).sum() # 更新正确分类的图片的数量

    print('Accuracy of the network on the 10000 test images: %.2f %%' % (100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 94.45 %

# %%
 # 定义2个存储每类中测试正确的个数的 列表，初始化为0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
# testloader = torch.utils.data.DataLoader(testset, batch_size=64,shuffle=True, num_workers=2)
net.eval()
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images = images.to(device)
        labels = labels.to(device)
        if hasattr(torch.cuda, 'empty_cache'):
            torch.cuda.empty_cache()
        outputs = net(images)

        _, predicted = torch.max(outputs.data, 1)
    #4组(batch_size)数据中，输出于label相同的，标记为1，否则为0
        c = (predicted == labels).squeeze()
        for i in range(len(images)):      # 因为每个batch都有4张图片，所以还需要一个4的小循环
            label = labels[i]   # 对各个类的进行各自累加
            class_correct[label] += c[i]
            class_total[label] += 1
 
 
for i in range(10):
    print('Accuracy of %5s : %.2f %%' % (classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of airplane : 94.40 %
# Accuracy of automobile : 97.10 %
# Accuracy of  bird : 92.70 %
# Accuracy of   cat : 88.40 %
# Accuracy of  deer : 95.70 %
# Accuracy of   dog : 90.40 %
# Accuracy of  frog : 96.70 %
# Accuracy of horse : 96.10 %
# Accuracy of  ship : 96.00 %
# Accuracy of truck : 95.20 %

# %%
dataiter = iter(testloader)
images, labels = dataiter.next()
images_ = images
#images_ = images_.view(images.shape[0], -1)
images_ = images_.to(device)
labels = labels.to(device)
val_output = net(images_)
_, val_preds = torch.max(val_output, 1)

fig = plt.figure(figsize=(25,4))

correct = torch.sum(val_preds == labels.data).item()


print("Accuracy Rate = {}%".format(correct/len(images) * 100))

fig = plt.figure(figsize=(25,25))
for idx in np.arange(64):    
    ax = fig.add_subplot(8, 8, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title("{}, ({})".format(classes[val_preds[idx].item()], classes[labels[idx].item()]), 
                 color = ("green" if val_preds[idx].item()==labels[idx].item() else "red"))
# Out:
# Accuracy Rate = 95.3125%

# %% [markdown]
# ### 8. 保存模型

# %%
torch.save(net,save_path[:-4]+'_'+str(epoch)+'.pth')
# torch.save(net, './model/ResNet50.pth')

# %% [markdown]
# ### 9. 预测

# %%
import torch
from PIL import Image
from torch.autograd import Variable
import torch.nn.functional as F
from torchvision import datasets, transforms
import numpy as np
 
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = densenet_cifar()

model = torch.load(save_path)  # 加载模型
# model = model.to('cuda')
model.eval()  # 把模型转为test模式

# 读取要预测的图片
img = Image.open("./airplane.jpg").convert('RGB') # 读取图像

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=450x300 at 0x1A9B9FE38C8>

# %%
trans = transforms.Compose([transforms.Scale((32,32)),
                            transforms.ToTensor(),
                            transforms.Normalize(mean=(0.5, 0.5, 0.5), 
                                                 std=(0.5, 0.5, 0.5)),
                           ])
 
img = trans(img)
img = img.to(device)
# 图片扩展多一维,因为输入到保存的模型中是4维的[batch_size,通道,长，宽]，而普通图片只有三维，[通道,长，宽]
img = img.unsqueeze(0)  
    # 扩展后，为[1，1，28，28]
output = model(img)
prob = F.softmax(output,dim=1) #prob是10个分类的概率
print("概率",prob)
value, predicted = torch.max(output.data, 1)
print("类别",predicted.item())
print(value)
pred_class = classes[predicted.item()]
print("分类",pred_class)
# Out:
# c:\users\86137\appdata\local\programs\python\python37\lib\site-packages\torchvision\transforms\transforms.py:285: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   warnings.warn("The use of the transforms.Scale transform is deprecated, " +
# 概率 tensor([[1.0000e+00, 1.0174e-07, 7.5823e-08, 3.2831e-09, 3.1316e-07, 2.4722e-08,
#          1.0737e-08, 5.8751e-08, 7.7517e-07, 2.0642e-08]], device='cuda:0',
#        grad_fn=<SoftmaxBackward>)
# 类别 0
# tensor([15.1289], device='cuda:0')
# 分类 plane

# %%
import requests
from PIL import Image
url = 'https://dss2.bdstatic.com/70cFvnSh_Q1YnxGkpoWK1HF6hhy/it/u=947072664,3925280208&fm=26&gp=0.jpg'
url = 'https://ss0.bdstatic.com/70cFuHSh_Q1YnxGkpoWK1HF6hhy/it/u=2952045457,215279295&fm=26&gp=0.jpg'
url = 'https://ss0.bdstatic.com/70cFvHSh_Q1YnxGkpoWK1HF6hhy/it/u=2838383012,1815030248&fm=26&gp=0.jpg'
url = 'https://gimg2.baidu.com/image_search/src=http%3A%2F%2Fwww.goupuzi.com%2Fnewatt%2FMon_1809%2F1_179223_7463b117c8a2c76.jpg&refer=http%3A%2F%2Fwww.goupuzi.com&app=2002&size=f9999,10000&q=a80&n=0&g=0n&fmt=jpeg?sec=1624346733&t=36ba18326a1e010737f530976201326d'
url = 'https://ss3.bdstatic.com/70cFv8Sh_Q1YnxGkpoWK1HF6hhy/it/u=2799543344,3604342295&fm=224&gp=0.jpg'
# url = 'https://ss1.bdstatic.com/70cFuXSh_Q1YnxGkpoWK1HF6hhy/it/u=2032505694,2851387785&fm=26&gp=0.jpg'
response = requests.get(url, stream=True)
print (response)
img = Image.open(response.raw)
img
# Out:
# <Response [200]>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500 at 0x1AA71D82EC8>

# %%
trans = transforms.Compose([transforms.Scale((32,32)),
                            transforms.ToTensor(),
                            transforms.Normalize(mean=(0.5, 0.5, 0.5), 
                                                 std=(0.5, 0.5, 0.5)),
                           ])
 
img = trans(img)
img = img.to(device)
# 图片扩展多一维,因为输入到保存的模型中是4维的[batch_size,通道,长，宽]，而普通图片只有三维，[通道,长，宽]
img = img.unsqueeze(0)  
    # 扩展后，为[1，1，28，28]
output = model(img)
prob = F.softmax(output,dim=1) #prob是10个分类的概率
print("概率",prob)
value, predicted = torch.max(output.data, 1)
print("类别",predicted.item())
print(value)
pred_class = classes[predicted.item()]
print("分类",pred_class)
# Out:
# 概率 tensor([[2.9429e-05, 2.3590e-07, 2.0532e-05, 9.9990e-01, 3.5278e-06, 4.0801e-05,
#          6.6553e-08, 4.6464e-07, 4.5989e-06, 4.0201e-06]], device='cuda:0',
#        grad_fn=<SoftmaxBackward>)
# 类别 3
# tensor([11.4969], device='cuda:0')
# 分类 cat
# c:\users\86137\appdata\local\programs\python\python37\lib\site-packages\torchvision\transforms\transforms.py:285: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   warnings.warn("The use of the transforms.Scale transform is deprecated, " +
